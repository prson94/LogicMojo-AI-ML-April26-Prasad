# %% [markdown]
# <a href="https://colab.research.google.com/github/prson94/LogicMojo-AI-ML-April26-Prasad/blob/main/Python_Refresher1_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
type(a)
a = 'Prasad'
type(a)
# Out:
# str

# %% [markdown]
# #List

# %%
lst = [5,1,2,78,4,5,3,'Prasad']
print(lst)
lst.append(788)
print(lst)
lst.insert(3,123)
print(lst)
lst.pop(-1)
print(lst)
lst.extend(['Kashavi',120.1])
print(lst)
# Out:
# [5, 1, 2, 78, 4, 5, 3, 'Prasad']
# [5, 1, 2, 78, 4, 5, 3, 'Prasad', 788]
# [5, 1, 2, 123, 78, 4, 5, 3, 'Prasad', 788]
# [5, 1, 2, 123, 78, 4, 5, 3, 'Prasad']
# [5, 1, 2, 123, 78, 4, 5, 3, 'Prasad', 'Kashavi', 120.1]

# %% [markdown]
# #Tuple

# %%
tup = (10.0,20.0,10.0,'Prasad')
print(tup)
tup.index(10.0,1)
tup = (10.0, 20.0, 24.0)
print(tup)
# Out:
# (10.0, 20.0, 10.0, 'Prasad')
# (10.0, 20.0, 24.0)

# %% [markdown]
# #Set

# %%
se = {1,2,7,2,1,6,5,'Prasad'}
print(se)
se.add('Kashavi')
print(se)
# Out:
# {1, 2, 'Prasad', 5, 6, 7}
# {1, 2, 'Prasad', 5, 6, 7, 'Kashavi'}

# %% [markdown]
# #FrozenSet

# %%
fse = frozenset([1,2,4,5,6,'Prasad',2])
print(fse)
# Out:
# frozenset({1, 2, 4, 5, 6, 'Prasad'})

# %% [markdown]
# #Dictionary

# %%
dict = {"Prasad":30, "Kashavi":1, 2 :2}
print(dict)
print(dict.get("Prasad"))
print(dict.get("Rutuja", 28))
print(dict.keys())
print(dict.values())
# Out:
# {'Prasad': 30, 'Kashavi': 1, 2: 2}
# 30
# 28
# dict_keys(['Prasad', 'Kashavi', 2])
# dict_values([30, 1, 2])

# %% [markdown]
# #Input

# %%
numbers = input("Enter numbers seperated by space:").split()
print(numbers)
numbers = [int(num) for num in numbers]
print(numbers)
# Out:
# Enter numbers seperated by space:1 2 2 4 6
# ['1', '2', '2', '4', '6']
# [1, 2, 2, 4, 6]
